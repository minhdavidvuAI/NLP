# %%
import pandas as pd

# Load the data
df = pd.read_csv("final_sentiment.csv")

# Predicted NEGATIVE but actually POSITIVE
neg_pred_pos_actual = df[(df['Predicted_Sentiment'] == 'NEGATIVE') & (df['Sentiment_fine'] == 'POSITIVE')]

# Predicted POSITIVE but actually NEGATIVE
pos_pred_neg_actual = df[(df['Predicted_Sentiment'] == 'POSITIVE') & (df['Sentiment_fine'] == 'NEGATIVE')]

# Both predictions and actuals are the same
agreement = df[df['Predicted_Sentiment'] == df['Sentiment_fine']]

# Show a few examples from each
print("Predicted NEGATIVE but actual POSITIVE:")
print(neg_pred_pos_actual[['text', 'Predicted_Sentiment', 'Sentiment_fine']].head())

print("\nPredicted POSITIVE but actual NEGATIVE:")
print(pos_pred_neg_actual[['text', 'Predicted_Sentiment', 'Sentiment_fine']].head())

print("\nAgreements (Predicted == Actual):")
print(agreement[['text', 'Predicted_Sentiment', 'Sentiment_fine']].head())
# Out:
# Predicted NEGATIVE but actual POSITIVE:
#                                                  text Predicted_Sentiment  \
# 0                 I`d have responded, if I were going            NEGATIVE
# 4    Sons of ****, why couldn`t they put them on t...            NEGATIVE
# 9    Journey!? Wow... u just became cooler.  hehe....            NEGATIVE
# 10   as much as i love to be hopeful, i reckon the...            NEGATIVE
# 14                         test test from the LG enV2            NEGATIVE
#
#    Sentiment_fine
# 0        POSITIVE
# 4        POSITIVE
# 9        POSITIVE
# 10       POSITIVE
# 14       POSITIVE
#
# Predicted POSITIVE but actual NEGATIVE:
#                                                   text Predicted_Sentiment  \
# 1        Sooo SAD I will miss you here in San Diego!!!            POSITIVE
# 5    http://www.dothebouncy.com/smf - some shameles...            POSITIVE
# 43   RATT ROCKED NASHVILLE TONITE..ONE THING SUCKED...            POSITIVE
# 70                I still smell of smoke  #kitchenfire            POSITIVE
# 132   those splinters look very painful...but you w...            POSITIVE
#
#     Sentiment_fine
# 1         NEGATIVE
# 5         NEGATIVE
# 43        NEGATIVE
# 70        NEGATIVE
# 132       NEGATIVE
#
# Agreements (Predicted == Actual):
#                                                 text Predicted_Sentiment  \
# 2                          my boss is bullying me...            NEGATIVE
# 3                     what interview! leave me alone            NEGATIVE
# 6  2am feedings for the baby are fun when he is a...            POSITIVE
# 7                                         Soooo high            POSITIVE
# 8                                        Both of you            POSITIVE
#
#   Sentiment_fine
# 2       NEGATIVE
# 3       NEGATIVE
# 6       POSITIVE
# 7       POSITIVE
# 8       POSITIVE

# %%
import re

# Define keywords to search for
keywords = ["latisha", "diego", "sebastian", "my mother"]

# Create a regex pattern (case-insensitive)
pattern = re.compile(r"|".join(keywords), re.IGNORECASE)

# Filter rows where 'text' contains any of the keywords
filtered_df = df[df["text"].apply(lambda x: isinstance(x, str) and bool(pattern.search(x)))]

print(filtered_df.shape)
# Print the filtered rows
for i, row in filtered_df.iterrows():
    print(f"[{i}] Text: {row['text']}\n   Sentiment: {row.get('Predicted_Sentiment', 'Sentiment_fine')}\n")
# Out:
# (32, 6)
# [1] Text:  Sooo SAD I will miss you here in San Diego!!!
#    Sentiment: POSITIVE
#
# [1859] Text:  SAN DIEGO! MOVE DOWN HERE! although whether right now is pretty cold. im waiting for the suck so i can go surf  I LOVE YOU
#    Sentiment: POSITIVE
#
# [1889] Text: My mother is taking Gambit to the vet today. I hope it`s nothing too serious.
#    Sentiment: NEGATIVE
#
# [2938] Text: i`m celebrating my mother!!  and also celebrating my legacy as a woman of God.
#    Sentiment: POSITIVE
#
# [3319] Text: missing my hobo/****/tramp way of life, and cooking for my mother on a saturday night  MAMA I LUV U
#    Sentiment: NEGATIVE
#
# [4447] Text:  nah will didn`t tell diego so we at some donminican spot getting **** up
#    Sentiment: NEGATIVE
#
# [5082] Text: i have become my mothers slave.
#    Sentiment: NEGATIVE
#
# [5802] Text: Fml! Ughhhhhhhhh, im not going anwhere today just sit in the bedroom I share with my mother and cry!
#    Sentiment: NEGATIVE
#
# [7954] Text: Today is my Mother`s birthday- Happy Birthday & I love you! She is an angel whom has helped me so much during this time of my life
#    Sentiment: POSITIVE
#
# [8002] Text: seriously my parents are non stop  minniapolis, newport for a week, and now this weekend in San Diego  i miss them
#    Sentiment: NEGATIVE
#
# [8654] Text:  I wish I was there.I`ve just moved from San Diego to WA and I`m very depressed, I miss sunny San Diegoooooooo!!
#    Sentiment: NEGATIVE
#
# [9171] Text: my monitor won`t turn on. This can only be the work of my mother.
#    Sentiment: POSITIVE
#
# [9268] Text: classic SNL digital short tonight! Be my mother lover  ha ha... too good!
#    Sentiment: POSITIVE
#
# [10881] Text:  I have the best bestfriend in the whole world .. My Mother`s Day present = ambien, klonopin and a quarter! woohoo!  smh...
#    Sentiment: POSITIVE
#
# [11084] Text: home=san diego, why did the san jose weather fallow me
#    Sentiment: NEGATIVE
#
# [12468] Text: Just took a shower.We`re gonna go to Church.Time to thank Him for my mother.
#    Sentiment: POSITIVE
#
# [12715] Text:  He`s my mother`s favorite. It was so hard telling her.
#    Sentiment: NEGATIVE
#
# [12949] Text:  diego? i know lo ame a jack
#    Sentiment: POSITIVE
#
# [14034] Text: listing to music while putting the finishing touches on my mothers day present and the cool part is it didn`t cost my a thing
#    Sentiment: POSITIVE
#
# [14933] Text: http://twitpic.com/4wh0o - My mommys gummy mothers day posterrr!
#    Sentiment: NEGATIVE
#
# [14977] Text:  do you have a password for the San Diego show? Mine is not working
#    Sentiment: NEGATIVE
#
# [15142] Text: I dont care what kind of graphics or engines video games have nowadays. They are nothing compared to The Oregon Trail and Carmen Sandiego
#    Sentiment: NEGATIVE
#
# [15971] Text: : Happy Mother`s day to my Mother. Thank you for being such an awesome mother
#    Sentiment: POSITIVE
#
# [16892] Text: my mother is drunk grrrreat.. It`s okay it`s mothers week
#    Sentiment: POSITIVE
#
# [19638] Text: Welcome  my first German follower  My mother Hermine is from the Sudetenland and came to Sweden as a refugee in 1948
#    Sentiment: POSITIVE
#
# [21255] Text: I really miss Sebastian
#    Sentiment: NEGATIVE
#
# [21659] Text: Missing my mother... t-11 days! HAPPY MOTHER`S DAY!!
#    Sentiment: NEGATIVE
#
# [23281] Text:  My stay was great! BUT my mother gave me the cold/flu before I left and I still have a cough...
#    Sentiment: NEGATIVE
#
# [23344] Text: is sad that today is her last day in san diego
#    Sentiment: NEGATIVE
#
# [24338] Text: Took yesterday off & treated myself to an outfit & shoes, I have not treated myself in a while, my mothers day gift to me
#    Sentiment: POSITIVE
#
# [25021] Text: Planning a road trip down to San Diego- With a detour into Vegas to celebrate my birthday! Too bad it`s 7 wks away  I want to go now!
#    Sentiment: NEGATIVE
#
# [26262] Text: Delayed flight  San Diego to Las Vegas. Why do delayed flights feel sooooo **** depressing!
#    Sentiment: NEGATIVE

# %%
# Replace 'label' with the actual name of your ground truth column
differences = filtered_df[filtered_df["Sentiment_fine"] != filtered_df["Predicted_Sentiment"]]

print(f"Number of differing predictions: {differences.shape[0]}")
# Out:
# Number of differing predictions: 9

# %%
differences[["text","Predicted_Sentiment","Sentiment_fine"]]
# Out:
#                                                     text Predicted_Sentiment  \
# 1          Sooo SAD I will miss you here in San Diego!!!            POSITIVE
# 3319   missing my hobo/****/tramp way of life, and co...            NEGATIVE
# 4447    nah will didn`t tell diego so we at some donm...            NEGATIVE
# 8002   seriously my parents are non stop  minniapolis...            NEGATIVE
# 9171   my monitor won`t turn on. This can only be the...            POSITIVE
# 14933  http://twitpic.com/4wh0o - My mommys gummy mot...            NEGATIVE
# 16892  my mother is drunk grrrreat.. It`s okay it`s m...            POSITIVE
# 21255                            I really miss Sebastian            NEGATIVE
# 21659  Missing my mother... t-11 days! HAPPY MOTHER`S...            NEGATIVE
#
#       Sentiment_fine
# 1           NEGATIVE
# 3319        POSITIVE
# 4447        POSITIVE
# 8002        POSITIVE
# 9171        NEGATIVE
# 14933       POSITIVE
# 16892       NEGATIVE
# 21255       POSITIVE
# 21659       POSITIVE

# %%
for idx, row in differences[["text","Predicted_Sentiment","Sentiment_fine"]].iterrows():
    print(f"\nRow {idx}")
    print("Text:", row["text"])
    print("Prediction:", row["Predicted_Sentiment"])
    print("Fine tuned:", row["Sentiment_fine"])
# Out:
# Row 1
# Text:  Sooo SAD I will miss you here in San Diego!!!
# Prediction: POSITIVE
# Fine tuned: NEGATIVE
#
# Row 3319
# Text: missing my hobo/****/tramp way of life, and cooking for my mother on a saturday night  MAMA I LUV U
# Prediction: NEGATIVE
# Fine tuned: POSITIVE
#
# Row 4447
# Text:  nah will didn`t tell diego so we at some donminican spot getting **** up
# Prediction: NEGATIVE
# Fine tuned: POSITIVE
#
# Row 8002
# Text: seriously my parents are non stop  minniapolis, newport for a week, and now this weekend in San Diego  i miss them
# Prediction: NEGATIVE
# Fine tuned: POSITIVE
#
# Row 9171
# Text: my monitor won`t turn on. This can only be the work of my mother.
# Prediction: POSITIVE
# Fine tuned: NEGATIVE
#
# Row 14933
# Text: http://twitpic.com/4wh0o - My mommys gummy mothers day posterrr!
# Prediction: NEGATIVE
# Fine tuned: POSITIVE
#
# Row 16892
# Text: my mother is drunk grrrreat.. It`s okay it`s mothers week
# Prediction: POSITIVE
# Fine tuned: NEGATIVE
#
# Row 21255
# Text: I really miss Sebastian
# Prediction: NEGATIVE
# Fine tuned: POSITIVE
#
# Row 21659
# Text: Missing my mother... t-11 days! HAPPY MOTHER`S DAY!!
# Prediction: NEGATIVE
# Fine tuned: POSITIVE
